# %% [markdown]
# ####Project: Customer Revenue Analytics - Lakeflow
#
# Defines catalog, schemas and table names used by all jobs

# %% [markdown]
# RAW/SILVER/GOLD - Define Tables

# %%
catalog = "customer_revenue_analytics"

# %%
raw_schema = "raw"
silver_schema = "silver"
gold_schema = "gold"

# %%
users_table = f"{catalog}.{raw_schema}.cralf_users"
products_table = f"{catalog}.{raw_schema}.cralf_products"
orders_table = f"{catalog}.{raw_schema}.cralf_orders"

# %%
enriched_orders_table = f"{catalog}.{silver_schema}.cralf_enriched_orders"

# %%
customer_revenue_table = f"{catalog}.{gold_schema}.cralf_customer_revenue"
product_revenue_table = f"{catalog}.{gold_schema}.cralf_product_revenue"

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS customer_revenue_analytics.raw;
CREATE SCHEMA IF NOT EXISTS customer_revenue_analytics.silver;
CREATE SCHEMA IF NOT EXISTS customer_revenue_analytics.gold;

# %% [markdown]
# Create the Parameter

# %%
dbutils.widgets.text("processing_date","")

# %%
processing_date = dbutils.widgets.get("processing_date")

# %%
from datetime import date

if processing_date == "":
    processing_date = str(date.today())

print(processing_date)

# %%
# spark.config.set("spark.sql.shuffle.partitions","200")
# spark.config.set("spark.databricks.delta.optimizeWrite.enabled","True")
# spark.config.set("spark.databricks.delta.autoCompact.enabled","True")

# %%
print("Users Table:", users_table)
print("Products Table:", products_table)
print("Orders Table:", orders_table)
print("Processing Date:", processing_date)
